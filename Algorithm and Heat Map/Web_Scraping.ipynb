# %%
import urllib.request,sys,time
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
url="https://zeenews.india.com/tags/delhi-crime.html"
page=urlopen(url)

# %%
page=requests.get(url)

# %%
page.status_code
# Out:
# 200

# %%
soup=BeautifulSoup(page.text,"html.parser")

# %%
l2=[]
for sin in soup.select('div[class="news_title"]'):
  course_name = sin.find("a").get_text()
  l2.append(course_name)
l2
# Out:
# ["Gangrape with Student of Class 5 in Delhi's Ghazipur",
#  'Delhi: 24-Year-Old Man, Stressed Over Medical Bills, Dies By Suicide In Hotel',
#  "*Delhi Woman, Who Was Pushed Inside Car, Blames 'Misunderstanding With Fiance'",
#  'Delhi Case: Dead body find in Sarai Kale Khan area',
#  'Video: Delhi Man Drags Woman By Hair, Beats Her And Forces Her To Sit In Car',
#  'Video: Delhi Man Slits His Throat In Public, Roams Around With Knife, Pistol',
#  "Highly Decomposed Body Of Tourist Found In Delhi's Geeta Colony Area",
#  'Delhi News: Uproar witnesses near Nathu Colony Chowk',
#  '2 Killed, 8 Injured After Thar Driver Loses Control In Delhi',
#  '16-Year-Old Girl Shot At By Friend In Delhi Over Argument',
#  'Teen Delhi Girl Allegedly Raped by Gurugram-Based Instagram Friend for a Year',
#  'Top 5 Works of the National-Award-Winning Director Sudhanshu Saria',
#  "'Those who Attacked my House Believe in Nathuram Godse's Ideology': Owaisi",
# ...

# %%
url="https://www.indiatvnews.com/topic/delhi-crime"
page=requests.get(url)

# %%
page.status_code
# Out:
# 200

# %%
soup=BeautifulSoup(page.text,"html.parser")

# %%
for sin in soup.select('h3[class="title"]'):
  course_name = sin.find("a").get_text()
  l2.append(course_name)

# %%
url="https://indianexpress-com.translate.goog/about/delhi-crime/?_x_tr_sl=en&_x_tr_tl=hi&_x_tr_hl=hi&_x_tr_pto=tc"
page=requests.get(url)

# %%
soup=BeautifulSoup(page.text,"html.parser")

for sin in soup.select('h3[class=""]'):
  course_name = sin.find("a").get_text()
  l2.append(course_name)

# %%
l2
# Out:
# ["Gangrape with Student of Class 5 in Delhi's Ghazipur",
#  'Delhi: 24-Year-Old Man, Stressed Over Medical Bills, Dies By Suicide In Hotel',
#  "*Delhi Woman, Who Was Pushed Inside Car, Blames 'Misunderstanding With Fiance'",
#  'Delhi Case: Dead body find in Sarai Kale Khan area',
#  'Video: Delhi Man Drags Woman By Hair, Beats Her And Forces Her To Sit In Car',
#  'Video: Delhi Man Slits His Throat In Public, Roams Around With Knife, Pistol',
#  "Highly Decomposed Body Of Tourist Found In Delhi's Geeta Colony Area",
#  'Delhi News: Uproar witnesses near Nathu Colony Chowk',
#  '2 Killed, 8 Injured After Thar Driver Loses Control In Delhi',
#  '16-Year-Old Girl Shot At By Friend In Delhi Over Argument',
#  'Teen Delhi Girl Allegedly Raped by Gurugram-Based Instagram Friend for a Year',
#  'Top 5 Works of the National-Award-Winning Director Sudhanshu Saria',
#  "'Those who Attacked my House Believe in Nathuram Godse's Ideology': Owaisi",
# ...

# %%
url="https://www.indiatoday.in/crime"
page=requests.get(url)

# %%
soup=BeautifulSoup(page.text,"html.parser")

for sin in soup.select('h2[class=""]'):
  course_name = sin.find("a").get_text()
  l2.append(course_name)

# %%
len(l2)
# Out:
# 70

# %%
url="https://www.news18.com/topics/delhi-crime/"
page=requests.get(url)

soup=BeautifulSoup(page.text,"html.parser")

for sin in soup.select('a[class="jsx-699491027"]'):
  course_name = sin.find("p").get_text()
  l2.append(course_name)

# %%
l2
# Out:
# ["Gangrape with Student of Class 5 in Delhi's Ghazipur",
#  'Delhi: 24-Year-Old Man, Stressed Over Medical Bills, Dies By Suicide In Hotel',
#  "*Delhi Woman, Who Was Pushed Inside Car, Blames 'Misunderstanding With Fiance'",
#  'Delhi Case: Dead body find in Sarai Kale Khan area',
#  'Video: Delhi Man Drags Woman By Hair, Beats Her And Forces Her To Sit In Car',
#  'Video: Delhi Man Slits His Throat In Public, Roams Around With Knife, Pistol',
#  "Highly Decomposed Body Of Tourist Found In Delhi's Geeta Colony Area",
#  'Delhi News: Uproar witnesses near Nathu Colony Chowk',
#  '2 Killed, 8 Injured After Thar Driver Loses Control In Delhi',
#  '16-Year-Old Girl Shot At By Friend In Delhi Over Argument',
#  'Teen Delhi Girl Allegedly Raped by Gurugram-Based Instagram Friend for a Year',
#  'Top 5 Works of the National-Award-Winning Director Sudhanshu Saria',
#  "'Those who Attacked my House Believe in Nathuram Godse's Ideology': Owaisi",
# ...

# %%
dt=pd.DataFrame(l2)

# %%
dt
# Out:
#                                                     0
# 0   Gangrape with Student of Class 5 in Delhi's Gh...
# 1   Delhi: 24-Year-Old Man, Stressed Over Medical ...
# 2   *Delhi Woman, Who Was Pushed Inside Car, Blame...
# 3   Delhi Case: Dead body find in Sarai Kale Khan ...
# 4   Video: Delhi Man Drags Woman By Hair, Beats He...
# ..                                                ...
# 85  Delhi Police To Integrate PCRs With Police Sta...
# 86  Delhi Hit And Run Case | Actor Shah Rukh Khan'...
# 87  Delhi Car Accident News: Delhi Police Accept L...
# 88  Delhi Road Accident: FSL Team To Inspect Car A...
# 89  Kanjhawala Road Accident | Nidhi Anjali Friend...
#
# [90 rows x 1 columns]

# %%
dt.columns=['Title']
dt
# Out:
#                                                 Title
# 0   Gangrape with Student of Class 5 in Delhi's Gh...
# 1   Delhi: 24-Year-Old Man, Stressed Over Medical ...
# 2   *Delhi Woman, Who Was Pushed Inside Car, Blame...
# 3   Delhi Case: Dead body find in Sarai Kale Khan ...
# 4   Video: Delhi Man Drags Woman By Hair, Beats He...
# ..                                                ...
# 85  Delhi Police To Integrate PCRs With Police Sta...
# 86  Delhi Hit And Run Case | Actor Shah Rukh Khan'...
# 87  Delhi Car Accident News: Delhi Police Accept L...
# 88  Delhi Road Accident: FSL Team To Inspect Car A...
# 89  Kanjhawala Road Accident | Nidhi Anjali Friend...
#
# [90 rows x 1 columns]

# %%
text = ' '.join(dt['Title'].tolist())

# create word cloud
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                min_font_size = 10).generate(text)

# plot word cloud
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %%
from collections import Counter

# %%
words = WordCloud().process_text(text)

# Count the occurrences of each word
word_counts = Counter(words)

# Get the most common words
most_common_words = word_counts.most_common(20)

# Print the most common words
print("Most common words:")
for word, count in most_common_words:
    print(word, count)

# Display the word cloud
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# Most common words:
# Delhi 60
# Man 17
# Woman 15
# Police 12
# car 10
# News 10
# Case 8
# Death 8
# Shot 7
# son 7
# Crime 7
# Accident 7
# killed 6
# Kanjhawala 6
# arrested 6
# held 6
# Year Old 6
# Man Stabbed 6
# Girl 5
# accused 5

# %%
l1=['Stabbed','killed','Accident','Crime','Shot']

# %%
result_df = dt[dt['Title'].str.contains('|'.join(l1), regex=True)]

print(result_df)
# Out:
#                                                 Title
# 9   16-Year-Old Girl Shot At By Friend In Delhi Ov...
# 13  Father-Son Duo Shot at Over Parking Dispute in...
# 17  Delhi Road Rage Case: Man Stabbed to Death in ...
# 21  Delhi Crime, Mismatched to Kota Factory: Netfl...
# 30  Muqabla: Delhi Police confirms Anjali Singh ki...
# 33  Delhi Kanjhawala Accident: Delhi reported a sh...
# 35  Delhi Crime Season 2, Darlings to CAT: Top 202...
# 38  Pandav Nagar murder: 'I didn't do it, my son k...
# 51  Woman returning after exam shot at, killed by ...
# 58  Gang war in Tihar Jail, Lawrance Bishnoi's gan...
# 70    18-Year-Old Man Stabbed to Death in South Delhi
# 74  Delhi Woman, Who Suffered Miscarriage After Be...
# 76  Delhi: Pregnant Woman Shot at by Neighbour Ove...
# 78  Yashaswini Dayama Can't Control Her Excitement...
# 79  'Delhi Crime 2' Team Wins Best Ensemble Cast A...
# 81  Caught on CCTV | Delhi Man Stabbed to Death Ov...
# ...

# %%
new_df = pd.read_csv('data/crime.csv')

# %%
ls = new_df['nm_pol'].str.lower().tolist()
ls.append('south delhi')
ls
# Out:
# ['chitranjan park',
#  'dabri',
#  'malviya nagar',
#  'chandni mahal',
#  'model town',
#  'anandvihar',
#  'kashmere gate',
#  'govind puri',
#  'bindapur',
#  'new friends colony',
#  'sarita vihar',
#  'timarpur',
#  'kanjhawala',
#  'anand parbat',
#  'sagarpur',
#  'prashant vihar',
#  'south campus',
#  'rohini south',
#  'punjabi bagh',
#  'dwarka north',
#  'burari',
#  'jama masjid',
#  'adrash nagar',
#  'chanakyapuri',
#  'pandav nagar',
#  'mianwali nagar',
#  'fatehpur beri',
#  'nabi karim',
#  'rajouri garden',
#  'jahangir puri',
#  'kamla market',
#  'barakhamba road',
#  'safdarjung enclave',
#  'mukherji nagar',
#  'farash bazar',
#  'kalkaji',
#  'kalkaji',
#  'parshad nagar',
#  'lodhi colony',
#  'inderpuri',
#  'okhla',
#  'samaypurbadli',
#  'jaffarpur kalan',
#  'maya puri',
#  'aman vihar',
#  'vijay vihar',
#  'amar colony',
#  'alipur',
#  'mahendra park',
#  'vasant kunj south',
#  'bhalswa dairy',
#  'bawana',
#  'begum pur',
#  'naraina',
# ...

# %%
result_df['Title'].str.lower()
# Out:
# 9     16-year-old girl shot at by friend in delhi ov...
# 13    father-son duo shot at over parking dispute in...
# 17    delhi road rage case: man stabbed to death in ...
# 21    delhi crime, mismatched to kota factory: netfl...
# 30    muqabla: delhi police confirms anjali singh ki...
# 33    delhi kanjhawala accident: delhi reported a sh...
# 35    delhi crime season 2, darlings to cat: top 202...
# 38    pandav nagar murder: 'i didn't do it, my son k...
# 51    woman returning after exam shot at, killed by ...
# 58    gang war in tihar jail, lawrance bishnoi's gan...
# 70      18-year-old man stabbed to death in south delhi
# 74    delhi woman, who suffered miscarriage after be...
# 76    delhi: pregnant woman shot at by neighbour ove...
# 78    yashaswini dayama can't control her excitement...
# 79    'delhi crime 2' team wins best ensemble cast a...
# 81    caught on cctv | delhi man stabbed to death ov...
# 83    delhi news | delhi crime news | delhi police u...
# ...
